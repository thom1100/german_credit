# %%
import pandas as pd

# %%
from utils import compute_costs, score

# %%
# to be defined from other notebooks
# in order to compute costs and score in the following cells
LoanAmount =
solution =
submission =

# %%
compute_costs(LoanAmount)

# %%
score(solution, submission)
